# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

def store_func():
    
    time.sleep(1.5)
    
    url = 'https://www.geekstore.store/collections/new-arrivals'# the url for the store
    
    k = requests.get(url).text # the response
    
    soup=BeautifulSoup(k,'html.parser') # use the beautifulsoup to parse the html
    price_list_raw = soup.find_all("div",class_="product-item__price-list price-list") # get the raw list of the prices
    
    

      
    price_list = [] # the clean list of prices
    
    for element in price_list_raw:
        price_list.append((element.text).replace(',','.').replace('\n','').strip()) # for loop to clean each item in the raw list
    
    
    soup = BeautifulSoup(k,'html.parser') # use beautifulsoup to parse the html
    name_list_raw = soup.find_all("a",class_="product-item__title text--strong link") # the raw list of items names
    
    name_list = [] # the clean list of prices

    for element in name_list_raw: 
        name_list.append((element.text).replace('\n','').strip()) # the for loop for cleaning each item in the raw list
        
    new_dict = {
        'items': name_list,
        'price': price_list,
        'store': 'GeekStore'
    } # the dict that is going to get changed into a dataframe
    
    return pd.DataFrame(new_dict) #return a dataframe

# %%
store_func()
# Out:
#                                                 items  \
# 0            Marvel Iron Man 1/1 Mk5 Helmet Automatic
# 1   Marvel Figure Fans Black Panther Pendant Zirco...
# 2   Thor Hammer Marvel Props Mjolnir Thor Hammer 1...
# 3            Marvel Japan VD53 Movement Avenger Watch
# 4               Marvel Avengers Captain America Watch
# 5                                  Marvel Venom Watch
# 6         Marvel Avengers Captain America Stell Watch
# 7                      Avengers Iron Man Marvel Watch
# 8                    Marvel Avengers Spider-Man Watch
# 9                            Marvel Avengers Iron Man
# 10                   Marvel Avengers Spider-Man Watch
# 11                Marvel Avenger Tourbillon Automatic
# 12                 Marvel Avenger Black Panther Watch
# 13  Marvel Licensed Stainless Steel Doctor Strange...
# 14                 Unisex Softstyle T-Shirt Rick Buda
# 15              Unisex Softstyle T-Shirt Majin Vegeta
# 16                     Unisex Softstyle T-Shirt Vader
# 17                     Unisex Softstyle T-Shirt Broly
# 18             Unisex Softstyle T-Shirt Vegeta Saiyan
# 19                  Unisex Softstyle T-Shirt Akatsuki
# 20                    Unisex Softstyle T-Shirt Mikasa
# 21               Unisex Softstyle T-Shirt Goku Saiyan
# 22                     Unisex Softstyle T-Shirt Evoli
# 23                      Unisex Softstyle T-Shirt Eren
# 24                      Unisex Softstyle T-Shirt Goku
# 25                      Unisex Softstyle T-Shirt Deku
# 26                    Unisex Softstyle T-Shirt Hunter
# 27                   Unisex Softstyle T-Shirt Uzumaki
# 28                   Unisex Softstyle T-Shirt Chopper
# 29                    Unisex Softstyle T-Shirt Pirate
# 30                     Unisex Softstyle T-Shirt Luffy
# 31                    Unisex Softstyle T-Shirt Hisoka
# 32                Men's Marvel Spider Torment T-Shirt
# 33  Women's Marvel Thor Love and Thunder Stormbrea...
# 34               Men's Marvel Captain Classic T-Shirt
# 35    Women's Marvel Ms Marvel Ms Marvel Icon T-Shirt
#
#                                     price      store
# 0   Sale price$249.99Regular price$349.99  GeekStore
# 1                        Sale price$49.99  GeekStore
# 2                       Sale price$219.99  GeekStore
# 3                       Sale price$229.99  GeekStore
# 4                       Sale price$229.99  GeekStore
# 5                       Sale price$249.99  GeekStore
# 6                       Sale price$229.99  GeekStore
# 7                       Sale price$299.99  GeekStore
# 8                       Sale price$249.99  GeekStore
# 9                       Sale price$249.99  GeekStore
# 10                      Sale price$249.99  GeekStore
# 11                      Sale price$499.99  GeekStore
# 12                      Sale price$499.99  GeekStore
# 13                      Sale price$299.99  GeekStore
# 14                  Sale priceFrom $19.99  GeekStore
# 15                  Sale priceFrom $19.99  GeekStore
# 16                  Sale priceFrom $19.99  GeekStore
# 17                  Sale priceFrom $19.99  GeekStore
# 18                  Sale priceFrom $19.99  GeekStore
# 19                  Sale priceFrom $19.99  GeekStore
# 20                  Sale priceFrom $19.99  GeekStore
# 21                  Sale priceFrom $19.99  GeekStore
# 22                  Sale priceFrom $19.99  GeekStore
# 23                  Sale priceFrom $19.99  GeekStore
# 24                  Sale priceFrom $19.99  GeekStore
# 25                  Sale priceFrom $19.99  GeekStore
# 26                  Sale priceFrom $19.99  GeekStore
# 27                  Sale priceFrom $19.99  GeekStore
# 28                  Sale priceFrom $19.99  GeekStore
# 29                  Sale priceFrom $19.99  GeekStore
# 30                  Sale priceFrom $19.99  GeekStore
# 31                  Sale priceFrom $19.99  GeekStore
# 32                  Sale priceFrom $22.50  GeekStore
# 33                  Sale priceFrom $22.50  GeekStore
# 34                  Sale priceFrom $22.50  GeekStore
# 35                  Sale priceFrom $22.50  GeekStore

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

def store_func(url,store_name):
    
    time.sleep(1.5)
    

    
    k = requests.get(url).text # the response
    
    soup=BeautifulSoup(k,'html.parser') # use the beautifulsoup to parse the html
    price_list_raw = soup.find_all("span",class_="price high-light") # get the raw list of the prices
    
    

      
    price_list = [] # the clean list of prices
    
    for element in price_list_raw:
        price_list.append((element.text).replace(',','.').replace('\n','').strip()) # for loop to clean each item in the raw list
    
    soup = BeautifulSoup(k,'html.parser') # use beautifulsoup to parse the html
    descr_list_raw = soup2.find_all("div",class_="product-title") # the raw list of items names
    
    descr_list= [] # the clean list of descriptions of items
    
    for element in descr_list_raw: 
        descr_list.append((element.text).replace('\n','').strip()) # the for loop for cleaning each item in the raw list
    
    soup = BeautifulSoup(k,'html.parser') # use beautifulsoup to parse the html
    name_list_raw = soup.find_all("div",class_="manufacturer-title") # the raw list of items names
    
    name_list = [] # the clean list of prices

    for element in name_list_raw: 
        name_list.append((element.text).replace('\n','').strip()) # the for loop for cleaning each item in the raw list
        
    new_dict = {
        'items': name_list,
        'description':descr_list,
        'price': price_list,
        'store': store_name
    } # the dict that is going to get changed into a dataframe
    
    return pd.DataFrame(new_dict) #return a dataframe

# %%
#ulr = 'https://www.bergfreunde.eu/outlet/outdoor-clothing/for--men/'
#price_tag = "span",class_="price high-light"
#name_tag = "div",class_="manufacturer-title"
#store_name = 'bergfreunde'

store_func('https://www.bergfreunde.eu/outlet/outdoor-clothing/for--men/','bergfreunde')
# Out:
#            items                             description          price  \
# 0    Bergfreunde       Recyled Seamless HeadbandHeadband        € 12.57
# 1        Haglöfs        Rugged Flex PantWalking trousers       € 111.97
# 2         H.A.D.                     OriginalsTube scarf    from € 7.18
# 3    ARMEDANGELS               Jaames Sound WavesT-shirt        € 22.72
# 4          Stoic             Wool NalluSt. II MittGloves        € 59.98
# ..           ...                                     ...            ...
# 67          CHPO          Erica PolarizedCycling glasses        € 33.96
# 68  Maier Sports                               OlleParka  from € 239.96
# 69       Chillaz  Rofan Pant 2.0 CordBouldering trousers       € 101.96
# 70      Bioracer                  Hat TempestCycling cap   from € 24.61
# 71     Patagonia      Reversible Bivy Down VestDown vest  from € 206.96
#
#           store
# 0   bergfreunde
# 1   bergfreunde
# 2   bergfreunde
# 3   bergfreunde
# 4   bergfreunde
# ..          ...
# 67  bergfreunde
# 68  bergfreunde
# 69  bergfreunde
# 70  bergfreunde
# 71  bergfreunde
#
# [72 rows x 4 columns]
